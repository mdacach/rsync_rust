# %%
import pandas as pd

full_data = pd.read_csv("linux_chunk_size_to_compression_ratio.csv")

# %%
full_data.describe()
# Out:
#          chunk_size    total_size  compression_ratio
# count     14.000000  1.400000e+01          14.000000
# mean    2405.000000  3.557466e+08          11.691429
# std     2992.446259  6.155175e+08           6.645132
# min       20.000000  7.122648e+07           0.580000
# 25%      312.500000  7.861485e+07           6.517500
# 50%     1250.000000  9.750782e+07          13.670000
# 75%     2875.000000  2.156510e+08          16.932500
# max    10000.000000  2.290970e+09          18.690000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x='chunk_size', y='compression_ratio', palette='flare', hue='compression_ratio', data=full_data)
plt.xlabel('block size used (in bytes)')
plt.ylabel('compression ratio')
plt.title("block size x compression ratio")
# Out:
# Text(0.5, 1.0, 'block size x compression ratio')
